# %%
## Mahalakshmi Padma Sri Harsha Maddu - mmaddu - 50246769
## Parikshit Sunil Deshmukh - pdeshmuk -  50247649

# %%
from nytimesarticle import articleAPI
api = articleAPI('3761b7d1f36742218377831a3e59edeb')
articles = api.search( q = "spacex", 
                      fq = {'headline':'SpaceX', 'source':['Reuters','AP', 'The New York Times']}, 
     begin_date = 20170303)
print(articles)
# Out:
# {u'status': u'OK', u'response': {u'docs': [{u'type_of_material': u'Video', u'blog': {}, u'byline': {u'person': [{u'qualifier': None, u'firstname': u'Spacex', u'title': None, u'middlename': None, u'lastname': None, u'rank': 1, u'role': u'reported', u'organization': u''}, {u'qualifier': None, u'firstname': None, u'title': None, u'middlename': None, u'lastname': None, u'rank': 2, u'role': u'reported', u'organization': u''}], u'original': u'By SPACEX, VIA REUTERS', u'organization': None}, u'score': 1.9342407, u'headline': {u'content_kicker': None, u'name': None, u'print_headline': None, u'kicker': None, u'seo': None, u'main': u'Watch the SpaceX Falcon Heavy Launch', u'sub': None}, u'multimedia': [{u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-articleLarge-v2.jpg', u'crop_name': u'articleLarge', u'rank': 0, u'height': 401, u'subtype': u'xlarge', u'legacy': {u'xlargewidth': 600, u'xlarge': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-articleLarge-v2.jpg', u'xlargeheight': 401}, u'subType': u'xlarge', u'caption': None, u'type': u'image', u'width': 600}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-thumbWide.jpg', u'crop_name': u'thumbWide', u'rank': 0, u'height': 126, u'subtype': u'wide', u'legacy': {u'wide': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-thumbWide.jpg', u'widewidth': 190, u'wideheight': 126}, u'subType': u'wide', u'caption': None, u'type': u'image', u'width': 190}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-thumbStandard-v2.jpg', u'crop_name': u'thumbStandard', u'rank': 0, u'height': 75, u'subtype': u'thumbnail', u'legacy': {u'thumbnailheight': 75, u'thumbnail': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-thumbStandard-v2.jpg', u'thumbnailwidth': 75}, u'subType': u'thumbnail', u'caption': None, u'type': u'image', u'width': 75}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-articleInline.jpg', u'crop_name': u'articleInline', u'rank': 0, u'height': 122, u'subtype': u'articleInline', u'legacy': {}, u'subType': u'articleInline', u'caption': None, u'type': u'image', u'width': 190}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blog225-v2.jpg', u'crop_name': u'blog225', u'rank': 0, u'height': 150, u'subtype': u'blog225', u'legacy': {}, u'subType': u'blog225', u'caption': None, u'type': u'image', u'width': 225}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blog427-v2.jpg', u'crop_name': u'blog427', u'rank': 0, u'height': 285, u'subtype': u'blog427', u'legacy': {}, u'subType': u'blog427', u'caption': None, u'type': u'image', u'width': 427}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blog480-v2.jpg', u'crop_name': u'blog480', u'rank': 0, u'height': 320, u'subtype': u'blog480', u'legacy': {}, u'subType': u'blog480', u'caption': None, u'type': u'image', u'width': 480}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blog533-v2.jpg', u'crop_name': u'blog533', u'rank': 0, u'height': 356, u'subtype': u'blog533', u'legacy': {}, u'subType': u'blog533', u'caption': None, u'type': u'image', u'width': 533}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blogSmallInline.jpg', u'crop_name': u'blogSmallInline', u'rank': 0, u'height': 97, u'subtype': u'blogSmallInline', u'legacy': {}, u'subType': u'blogSmallInline', u'caption': None, u'type': u'image', u'width': 151}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blogSmallThumb-v2.jpg', u'crop_name': u'blogSmallThumb', u'rank': 0, u'height': 50, u'subtype': u'blogSmallThumb', u'legacy': {}, u'subType': u'blogSmallThumb', u'caption': None, u'type': u'image', u'width': 50}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-facebookJumbo.jpg', u'crop_name': u'facebookJumbo', u'rank': 0, u'height': 550, u'subtype': u'facebookJumbo', u'legacy': {}, u'subType': u'faceboo ...

# %%
import math
hits = articles['response']['meta']['hits']
print("hits :" + str(hits))
ls = []
pages = int(math.ceil(hits/10))
for i in range(pages):
    print("collecting page " + str(i))
    articles['page'] = i
    for article in articles['response']['docs']:
        ar = article['web_url'].encode('utf-8')
        if not ar.__contains__("video"):
            ls.append(article['web_url'].encode('utf-8'))
        else:
            continue
print(ls)
# Out:
# hits :23
# collecting page 0
# collecting page 1
# ['https://www.nytimes.com/aponline/2018/04/04/science/ap-us-sci-space-station.html', 'https://www.nytimes.com/aponline/2018/03/30/us/ap-us-iridium-launch.html', 'https://www.nytimes.com/aponline/2018/04/02/science/ap-us-sci-space-station.html', 'https://www.nytimes.com/reuters/2018/03/30/business/30reuters-spacex-fcc.html', 'https://www.nytimes.com/reuters/2018/03/29/technology/29reuters-spacex-fcc.html', 'https://www.nytimes.com/interactive/2018/science/spacex-falcon-launch.html', 'https://www.nytimes.com/2018/02/08/briefing/the-week-in-good-news-spacex-black-panther.html', 'https://www.nytimes.com/2018/02/07/briefing/spacex-wall-street-poland.html', 'https://www.nytimes.com/2018/02/12/opinion/tesla-spacex-elon-musk.html', 'https://www.nytimes.com/aponline/2018/04/04/science/ap-us-sci-space-station.html', 'https://www.nytimes.com/aponline/2018/03/30/us/ap-us-iridium-launch.html', 'https://www.nytimes.com/aponline/2018/04/02/science/ap-us-sci-space-station.html', 'https://www.nytimes.com/reuters/2018/03/30/business/30reuters-spacex-fcc.html', 'https://www.nytimes.com/reuters/2018/03/29/technology/29reuters-spacex-fcc.html', 'https://www.nytimes.com/interactive/2018/science/spacex-falcon-launch.html', 'https://www.nytimes.com/2018/02/08/briefing/the-week-in-good-news-spacex-black-panther.html', 'https://www.nytimes.com/2018/02/07/briefing/spacex-wall-street-poland.html', 'https://www.nytimes.com/2018/02/12/opinion/tesla-spacex-elon-musk.html']

# %%
from bs4 import BeautifulSoup
import requests
import unicodedata

output = ""

for x in ls[:]:
    page = requests.get(x)
    soup = BeautifulSoup(page.content, 'html.parser')
    soup = soup.find('article')
    for script in soup(["script", "style"]):
        script.extract() 
    text = soup.text.strip()
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = ' '.join(chunk for chunk in chunks if chunk)
    output1 = text.encode('utf-8').strip()
    output = output + " " + output1

# %%
import re

cleanString = re.sub(r"[^a-zA-Z]+", ' ', output)
cleanString = ' '.join([w for w in cleanString.split() if len(w)>1])
cleanString = cleanString.lower()



cleanString = re.sub("new york Times", ' ', cleanString, flags=re.I)
cleanString = re.sub("main story", ' ', cleanString, flags=re.I)
cleanString = re.sub("continue reading", ' ', cleanString, flags=re.I)
cleanString = re.sub("advertisement continue", ' ', cleanString, flags=re.I)
cleanString = re.sub("york times", ' ', cleanString, flags=re.I)
cleanString = re.sub("page continue", ' ', cleanString, flags=re.I)
cleanString = re.sub("page tell", ' ', cleanString, flags=re.I)
cleanString = re.sub("story share", ' ', cleanString, flags=re.I)
cleanString = re.sub("page continue", ' ', cleanString, flags=re.I)
cleanString = re.sub("tell us", ' ', cleanString, flags=re.I)
cleanString = re.sub("story advertisement", ' ', cleanString, flags=re.I)
cleanString = re.sub("contact us", ' ', cleanString, flags=re.I)
cleanString = re.sub("email preferences", ' ', cleanString, flags=re.I)
cleanString = re.sub("newsletter sign", ' ', cleanString, flags=re.I)
cleanString = re.sub("email view", ' ', cleanString, flags=re.I)
cleanString = re.sub("policy opt", ' ', cleanString, flags=re.I)
cleanString = re.sub("manage email", ' ', cleanString, flags=re.I)
cleanString = re.sub("select newsletter", ' ', cleanString, flags=re.I)
cleanString = re.sub("address please", ' ', cleanString, flags=re.I)
cleanString = re.sub("times newsletters", ' ', cleanString, flags=re.I)
cleanString = re.sub("receive occasional", ' ', cleanString, flags=re.I)
cleanString = re.sub("box invalid", ' ', cleanString, flags=re.I)
cleanString = re.sub("Please try", ' ', cleanString, flags=re.I)
cleanString = re.sub("occurred please", ' ', cleanString, flags=re.I)
cleanString = re.sub("privacy policy", ' ', cleanString, flags=re.I)
cleanString = re.sub("invalid email", ' ', cleanString, flags=re.I)
cleanString = re.sub("occasional updates", ' ', cleanString, flags=re.I)
cleanString = re.sub("times products", ' ', cleanString, flags=re.I)
cleanString = re.sub("special offers", ' ', cleanString, flags=re.I)
cleanString = re.sub("must select", ' ', cleanString, flags=re.I)
cleanString = re.sub("services thank", ' ', cleanString, flags=re.I)
cleanString = re.sub("us anytime", ' ', cleanString, flags=re.I)
cleanString = re.sub("already subscribed", ' ', cleanString, flags=re.I)
cleanString = re.sub("email address", ' ', cleanString, flags=re.I)
cleanString = re.sub("please verify", ' ', cleanString, flags=re.I)
cleanString = re.sub("newsletters see", ' ', cleanString, flags=re.I)
cleanString = re.sub("sample manage", ' ', cleanString, flags=re.I)
cleanString = re.sub("see sample", ' ', cleanString, flags=re.I)
cleanString = re.sub("order reprints", ' ', cleanString, flags=re.I)
cleanString = re.sub("york edition", ' ', cleanString, flags=re.I)
cleanString = re.sub("today paper", ' ', cleanString, flags=re.I)
cleanString = re.sub("article appears", ' ', cleanString, flags=re.I)
cleanString = re.sub("reprints today", ' ', cleanString, flags=re.I)
cleanString = re.sub("subscribe continue", ' ', cleanString, flags=re.I)
cleanString = re.sub("paper subscribe", ' ', cleanString, flags=re.I)
cleanString = re.sub("think related", ' ', cleanString, flags=re.I)
cleanString = re.sub("related coverage", ' ', cleanString, flags=re.I)


with open("SpacexArticles.txt", "w") as text_file:
    text_file.write("%s" % cleanString)

# %%
from nytimesarticle import articleAPI
api = articleAPI('3761b7d1f36742218377831a3e59edeb')
articles = api.search( q = "Spacex", 
                      fq = {'headline':'Spacex', 'source':['Reuters','AP', 'The New York Times']}, 
     begin_date = 20180206, end_date = 20180207)
print(articles)
# Out:
# {u'status': u'OK', u'response': {u'docs': [{u'type_of_material': u'Video', u'blog': {}, u'byline': {u'person': [{u'qualifier': None, u'firstname': u'Spacex', u'title': None, u'middlename': None, u'lastname': None, u'rank': 1, u'role': u'reported', u'organization': u''}, {u'qualifier': None, u'firstname': None, u'title': None, u'middlename': None, u'lastname': None, u'rank': 2, u'role': u'reported', u'organization': u''}], u'original': u'By SPACEX, VIA REUTERS', u'organization': None}, u'score': 1.9305187, u'headline': {u'content_kicker': None, u'name': None, u'print_headline': None, u'kicker': None, u'seo': None, u'main': u'Watch the SpaceX Falcon Heavy Launch', u'sub': None}, u'multimedia': [{u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-articleLarge-v2.jpg', u'crop_name': u'articleLarge', u'rank': 0, u'height': 401, u'subtype': u'xlarge', u'legacy': {u'xlargewidth': 600, u'xlarge': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-articleLarge-v2.jpg', u'xlargeheight': 401}, u'subType': u'xlarge', u'caption': None, u'type': u'image', u'width': 600}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-thumbWide.jpg', u'crop_name': u'thumbWide', u'rank': 0, u'height': 126, u'subtype': u'wide', u'legacy': {u'wide': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-thumbWide.jpg', u'widewidth': 190, u'wideheight': 126}, u'subType': u'wide', u'caption': None, u'type': u'image', u'width': 190}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-thumbStandard-v2.jpg', u'crop_name': u'thumbStandard', u'rank': 0, u'height': 75, u'subtype': u'thumbnail', u'legacy': {u'thumbnailheight': 75, u'thumbnail': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-thumbStandard-v2.jpg', u'thumbnailwidth': 75}, u'subType': u'thumbnail', u'caption': None, u'type': u'image', u'width': 75}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-articleInline.jpg', u'crop_name': u'articleInline', u'rank': 0, u'height': 122, u'subtype': u'articleInline', u'legacy': {}, u'subType': u'articleInline', u'caption': None, u'type': u'image', u'width': 190}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blog225-v2.jpg', u'crop_name': u'blog225', u'rank': 0, u'height': 150, u'subtype': u'blog225', u'legacy': {}, u'subType': u'blog225', u'caption': None, u'type': u'image', u'width': 225}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blog427-v2.jpg', u'crop_name': u'blog427', u'rank': 0, u'height': 285, u'subtype': u'blog427', u'legacy': {}, u'subType': u'blog427', u'caption': None, u'type': u'image', u'width': 427}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blog480-v2.jpg', u'crop_name': u'blog480', u'rank': 0, u'height': 320, u'subtype': u'blog480', u'legacy': {}, u'subType': u'blog480', u'caption': None, u'type': u'image', u'width': 480}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blog533-v2.jpg', u'crop_name': u'blog533', u'rank': 0, u'height': 356, u'subtype': u'blog533', u'legacy': {}, u'subType': u'blog533', u'caption': None, u'type': u'image', u'width': 533}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blogSmallInline.jpg', u'crop_name': u'blogSmallInline', u'rank': 0, u'height': 97, u'subtype': u'blogSmallInline', u'legacy': {}, u'subType': u'blogSmallInline', u'caption': None, u'type': u'image', u'width': 151}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-blogSmallThumb-v2.jpg', u'crop_name': u'blogSmallThumb', u'rank': 0, u'height': 50, u'subtype': u'blogSmallThumb', u'legacy': {}, u'subType': u'blogSmallThumb', u'caption': None, u'type': u'image', u'width': 50}, {u'credit': None, u'url': u'images/2018/02/08/nyregion/07SPACEX3/07SPACEX3-facebookJumbo.jpg', u'crop_name': u'facebookJumbo', u'rank': 0, u'height': 550, u'subtype': u'facebookJumbo', u'legacy': {}, u'subType': u'faceboo ...

# %%
import math
hits = articles['response']['meta']['hits']
print("hits :" + str(hits))
ls = []
pages = int(hits)
for i in range(pages):
    print("collecting page " + str(i))
    articles['page'] = i
    for article in articles['response']['docs']:
        ar = article['web_url'].encode('utf-8')
        if not ar.__contains__("video"):
            ls.append(article['web_url'].encode('utf-8'))
        else:
            continue
print(ls)
# Out:
# hits :5
# collecting page 0
# collecting page 1
# collecting page 2
# collecting page 3
# collecting page 4
# ['https://www.nytimes.com/2018/02/06/briefing/stock-markets-donald-trump-spacex.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-julian-assange-north-korea.html', 'https://www.nytimes.com/2018/02/06/science/falcon-heavy-spacex-launch.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-north-korea-black-panther.html', 'https://www.nytimes.com/2018/02/06/briefing/stock-markets-donald-trump-spacex.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-julian-assange-north-korea.html', 'https://www.nytimes.com/2018/02/06/science/falcon-heavy-spacex-launch.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-north-korea-black-panther.html', 'https://www.nytimes.com/2018/02/06/briefing/stock-markets-donald-trump-spacex.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-julian-assange-north-korea.html', 'https://www.nytimes.com/2018/02/06/science/falcon-heavy-spacex-launch.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-north-korea-black-panther.html', 'https://www.nytimes.com/2018/02/06/briefing/stock-markets-donald-trump-spacex.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-julian-assange-north-korea.html', 'https://www.nytimes.com/2018/02/06/science/falcon-heavy-spacex-launch.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-north-korea-black-panther.html', 'https://www.nytimes.com/2018/02/06/briefing/stock-markets-donald-trump-spacex.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-julian-assange-north-korea.html', 'https://www.nytimes.com/2018/02/06/science/falcon-heavy-spacex-launch.html', 'https://www.nytimes.com/2018/02/06/briefing/spacex-north-korea-black-panther.html']

# %%
from bs4 import BeautifulSoup
import requests
import unicodedata

output = ""

for x in ls[:]:
    page = requests.get(x)
    soup = BeautifulSoup(page.content, 'html.parser')
    soup = soup.find('article')
    for script in soup(["script", "style"]):
        script.extract() 
    text = soup.text.strip()
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = ' '.join(chunk for chunk in chunks if chunk)
    output1 = text.encode('utf-8').strip()
    output = output + " " + output1

# %%
import re

cleanString = re.sub(r"[^a-zA-Z]+", ' ', output)
cleanString = ' '.join([w for w in cleanString.split() if len(w)>1])
cleanString = cleanString.lower()



cleanString = re.sub("new york Times", ' ', cleanString, flags=re.I)
cleanString = re.sub("main story", ' ', cleanString, flags=re.I)
cleanString = re.sub("continue reading", ' ', cleanString, flags=re.I)
cleanString = re.sub("advertisement continue", ' ', cleanString, flags=re.I)
cleanString = re.sub("york times", ' ', cleanString, flags=re.I)
cleanString = re.sub("page continue", ' ', cleanString, flags=re.I)
cleanString = re.sub("page tell", ' ', cleanString, flags=re.I)
cleanString = re.sub("story share", ' ', cleanString, flags=re.I)
cleanString = re.sub("page continue", ' ', cleanString, flags=re.I)
cleanString = re.sub("tell us", ' ', cleanString, flags=re.I)
cleanString = re.sub("story advertisement", ' ', cleanString, flags=re.I)
cleanString = re.sub("contact us", ' ', cleanString, flags=re.I)
cleanString = re.sub("email preferences", ' ', cleanString, flags=re.I)
cleanString = re.sub("newsletter sign", ' ', cleanString, flags=re.I)
cleanString = re.sub("email view", ' ', cleanString, flags=re.I)
cleanString = re.sub("policy opt", ' ', cleanString, flags=re.I)
cleanString = re.sub("manage email", ' ', cleanString, flags=re.I)
cleanString = re.sub("select newsletter", ' ', cleanString, flags=re.I)
cleanString = re.sub("address please", ' ', cleanString, flags=re.I)
cleanString = re.sub("times newsletters", ' ', cleanString, flags=re.I)
cleanString = re.sub("receive occasional", ' ', cleanString, flags=re.I)
cleanString = re.sub("box invalid", ' ', cleanString, flags=re.I)
cleanString = re.sub("Please try", ' ', cleanString, flags=re.I)
cleanString = re.sub("occurred please", ' ', cleanString, flags=re.I)
cleanString = re.sub("privacy policy", ' ', cleanString, flags=re.I)
cleanString = re.sub("invalid email", ' ', cleanString, flags=re.I)
cleanString = re.sub("occasional updates", ' ', cleanString, flags=re.I)
cleanString = re.sub("times products", ' ', cleanString, flags=re.I)
cleanString = re.sub("special offers", ' ', cleanString, flags=re.I)
cleanString = re.sub("must select", ' ', cleanString, flags=re.I)
cleanString = re.sub("services thank", ' ', cleanString, flags=re.I)
cleanString = re.sub("us anytime", ' ', cleanString, flags=re.I)
cleanString = re.sub("already subscribed", ' ', cleanString, flags=re.I)
cleanString = re.sub("email address", ' ', cleanString, flags=re.I)
cleanString = re.sub("please verify", ' ', cleanString, flags=re.I)
cleanString = re.sub("newsletters see", ' ', cleanString, flags=re.I)
cleanString = re.sub("sample manage", ' ', cleanString, flags=re.I)
cleanString = re.sub("see sample", ' ', cleanString, flags=re.I)
cleanString = re.sub("order reprints", ' ', cleanString, flags=re.I)
cleanString = re.sub("york edition", ' ', cleanString, flags=re.I)
cleanString = re.sub("today paper", ' ', cleanString, flags=re.I)
cleanString = re.sub("article appears", ' ', cleanString, flags=re.I)
cleanString = re.sub("reprints today", ' ', cleanString, flags=re.I)
cleanString = re.sub("subscribe continue", ' ', cleanString, flags=re.I)
cleanString = re.sub("paper subscribe", ' ', cleanString, flags=re.I)
cleanString = re.sub("think related", ' ', cleanString, flags=re.I)
cleanString = re.sub("related coverage", ' ', cleanString, flags=re.I)


with open("SpacexArticles1Day.txt", "w") as text_file:
    text_file.write("%s" % cleanString)
